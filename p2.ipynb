# %%
import pandas as pd

# %%
df= pd.read_csv(r"New folder\dataset_train.csv")

# %%
df.loc[10681877]
# Out:
# timestamp          2022-06-01 10:21:24
# TP2                             -0.022
# TP3                             10.006
# H1                                 9.4
# DV_pressure                     -0.034
# Reservoirs                       1.466
# Oil_temperature                  76.55
# Flowmeter                    19.404688
# Motor_current                    3.975
# COMP                                 1
# DV_eletric                           0
# Towers                               1
# MPG                                  1
# LPS                                  0
# Pressure_switch                      0
# Oil_level                            0
# Caudal_impulses                      0
# gpsLong                       -8.65944
# gpsLat                         41.2125
# gpsSpeed                             1
# gpsQuality                           1
# Name: 10681877, dtype: object

# %%
df.tail()
# Out:
#                     timestamp    TP2    TP3     H1  DV_pressure  Reservoirs  \
# 10773583  2022-06-02 15:49:49 -0.010  8.444  8.204       -0.032       1.466
# 10773584  2022-06-02 15:49:50 -0.010  8.442  8.204       -0.034       1.466
# 10773585  2022-06-02 15:49:51 -0.010  8.438  8.202       -0.032       1.464
# 10773586  2022-06-02 15:49:52 -0.010  8.438  8.202       -0.032       1.466
# 10773587  2022-06-02 15:49:53 -0.008  8.438  8.200       -0.032       1.468
#
#           Oil_temperature  Flowmeter  Motor_current  COMP  ...  Towers  MPG  \
# 10773583           63.200  19.227156          0.005     1  ...       1    1
# 10773584           63.200  19.217813          0.005     1  ...       1    1
# 10773585           63.225  19.217813          0.005     1  ...       1    1
# 10773586           63.175  19.217813          0.005     1  ...       1    1
# 10773587           63.200  19.227156          0.005     1  ...       1    1
#
# ...

# %%
from sklearn.cluster import MiniBatchKMeans
import pandas as pd
import scipy.sparse.linalg
del df['timestamp']
# Assuming df is your pandas DataFrame with data to cluster

# Define the number of clusters you want
n_clusters = 5  # adjust this based on your needs

# Initialize the MiniBatchKMeans model
minibatch_kmeans = MiniBatchKMeans(n_clusters=n_clusters, batch_size=100, random_state=42)

# Fit the model to the data
minibatch_kmeans.fit(df)

# Get the cluster labels for each data point
df['cluster'] = minibatch_kmeans.labels_

# You can access the cluster centers and other attributes as well
cluster_centers = minibatch_kmeans.cluster_centers_

# Display the first few rows of the DataFrame with assigned clusters
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.cluster import MiniBatchKMeans
#       2 import pandas as pd
#       3 import scipy.sparse.linalg
#
# File c:\Users\hevar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\__init__.py:96
#      85 # `_distributor_init` allows distributors to run custom init code.
#      86 # For instance, for the Windows wheel, this is used to pre-load the
#      87 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      90 # later is linked to the OpenMP runtime to make it possible to introspect
#      91 # it and importing it first would fail if the OpenMP dll cannot be found.
#      92 from . import (
#      93     __check_build,  # noqa: F401
#      94     _distributor_init,  # noqa: F401
#      95 )
# ---> 96 from .base import clone
# ...
